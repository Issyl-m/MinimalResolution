# %% [markdown]
# <a href="https://colab.research.google.com/github/Issyl-m/MinimalResolution/blob/main/minrv1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt install -q git
# !pip install -q condacolab
import condacolab
condacolab.install()
# !mamba create -n min_resolution sage=10.4 plotly python=3.12.5 -c conda-forge -q
# !git clone https://github.com/Issyl-m/MinimalResolution.git # && cd MinimalResolution
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git is already the newest version (1:2.34.1-1ubuntu1.11).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.
# ⏬ Downloading https://github.com/conda-forge/miniforge/releases/download/23.11.0-0/Mambaforge-23.11.0-0-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:00:17
# 🔁 Restarting kernel...
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# Cloning into 'MinimalResolution'...
# remote: Enumerating objects: 183, done.
# remote: Counting objects: 100% (129/129), done.
# remote: Compressing objects: 100% (86/86), done.
# remote: Total 183 (delta 75), reused 86 (delta 36), pack-reused 54 (from 1)
# Receiving objects: 100% (183/183), 402.83 MiB | 23.05 MiB/s, done.
# Resolving deltas: 100% (92/92), done.
# Updating files: 100% (27/27), done.

# %%
# run this block on a separate cell
# %%shell
eval "$(conda shell.bash hook)" # copy conda command to shell
conda activate min_resolution
pip install jsons
cd MinimalResolution
./g.sh
# Out:
# Streaming output truncated to the last 5000 lines.
# Computing Yoneda product: 2, 9, 1 @@ 9, 9, 1
# Computing Yoneda product: 2, 9, 1 @@ 9, 26, 1
# Computing Yoneda product: 2, 9, 1 @@ 9, 28, 1
# Computing Yoneda product: 2, 9, 1 @@ 10, 10, 1
# Computing Yoneda product: 2, 9, 1 @@ 10, 28, 1
# Computing Yoneda product: 2, 9, 1 @@ 10, 29, 1
# Computing Yoneda product: 2, 9, 1 @@ 11, 11, 1
# Computing Yoneda product: 2, 9, 1 @@ 12, 12, 1
# Computing Yoneda product: 2, 9, 1 @@ 13, 13, 1
# Computing Yoneda product: 2, 9, 1 @@ 14, 14, 1
# Computing Yoneda product: 2, 9, 1 @@ 15, 15, 1
# Computing Yoneda product: 2, 9, 1 @@ 16, 16, 1
# Computing Yoneda product: 2, 9, 1 @@ 17, 17, 1
# Computing Yoneda product: 2, 9, 1 @@ 18, 18, 1
# Computing Yoneda product: 2, 9, 1 @@ 19, 19, 1
# Computing Yoneda product: 2, 9, 1 @@ 20, 20, 1
# Computing Yoneda product: 2, 9, 1 @@ 21, 21, 1
# Computing Yoneda product: 2, 9, 1 @@ 22, 22, 1
# Computing Yoneda product: 2, 9, 1 @@ 23, 23, 1
# ...
